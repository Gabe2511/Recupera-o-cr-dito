# %%
import pandas as pd
import numpy as np

import sqlite3
import matplotlib.pyplot as plt
import _mysql_connector

from sqlalchemy import create_engine
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
from pathlib import Path

csv_path = Path(r"C:\Users\scarl\Desktop\Recuperacao_credito\dados\base_recuperacao_credito_br.csv")
df = pd.read_csv(csv_path)

df.head()
# Out:
#    id_cliente  idade estado  dias_atraso  valor_divida  score_credito  \
# 0           1   60.0     RJ         28.0       1112.76          581.0
# 1           2   28.0     MG         26.0      17079.14          858.0
# 2           3   47.0     PR          8.0       1230.03          523.0
# 3           4   58.0     BA          6.0      14250.50            NaN
# 4           5   48.0     SP        150.0       7315.67          306.0
#
#           status data_contato
# 0           Pago   2025-04-25
# 1  Em Negociação   2025-10-30
# 2           Pago   2025-09-16
# 3         Acordo   2025-04-23
# 4           Pago   2025-12-24

# %%
df.info()

df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_cliente     60 non-null     int64
#  1   idade          59 non-null     float64
#  2   estado         60 non-null     object
#  3   dias_atraso    59 non-null     float64
#  4   valor_divida   59 non-null     float64
#  5   score_credito  59 non-null     float64
#  6   status         59 non-null     object
#  7   data_contato   59 non-null     object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 3.9+ KB
# id_cliente       0
# idade            1
# estado           0
# dias_atraso      1
# valor_divida     1
# score_credito    1
# status           1
# data_contato     1
# dtype: int64

# %%
df.fillna(df.median(numeric_only=True), inplace=True)

df.fillna("Não informado", inplace=True)

df["pagou"] = df["status"].apply(
    lambda x: "Sim" if x== "Pago" else "Não"
)

df["pagou"].value_counts(dropna=False)
df["status"].value_counts()
print(df[["status", "pagou"]].head(20))

len(df)
# Out:
#            status pagou
# 0            Pago   Sim
# 1   Em Negociação   Não
# 2            Pago   Sim
# 3          Acordo   Não
# 4            Pago   Sim
# 5    Inadimplente   Não
# 6        Cobrança   Não
# 7   Em Negociação   Não
# 8        Cobrança   Não
# 9    Inadimplente   Não
# 10   Inadimplente   Não
# 11  Em Negociação   Não
# 12           Pago   Sim
# 13           Pago   Sim
# 14   Inadimplente   Não
# 15   Inadimplente   Não
# 16           Pago   Sim
# 17   Inadimplente   Não
# 18           Pago   Sim
# 19           Pago   Sim
# 60

# %%
import sqlite3
from pathlib import Path

db_path = Path("..") / "recupera_credito.db"
con = sqlite3.connect(db_path)

# %%
df.to_sql(
    "clientes",
    con,
    if_exists="replace",
    index=False
)
# Out:
# 60

# %%
consulta = "SELECT * FROM clientes LIMIT 10"
resultado = pd.read_sql(consulta, con)

# %%
consulta = """

SELECT
    estado,
    AVG(valor_divida) AS media

FROM clientes
GROUP BY estado
ORDER BY media DESC

"""
resultado = pd.read_sql(consulta, con)
resultado
# Out:
#   estado         media
# 0     PR  13868.175833
# 1     SP  12731.942500
# 2     BA  12458.555000
# 3     MG  12119.561667
# 4     RJ  10938.622500

# %%
resultado.plot(
    x="estado",
    y="media",
    kind="bar",
    figsize=(10, 5),
    rot=0

)

plt.tight_layout()
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['id_cliente', 'idade', 'estado', 'dias_atraso', 'valor_divida', 'score_credito', 'status', 'data_contato', 'pagou']

# %%
print(df.columns.tolist())

if "pagou" not in df.columns:
    # exemplo: criar a coluna alvo a partir de status
    df["pagou"] = df["status"].eq("pago").astype(int)

X = df.drop(columns=["pagou"])
y = df["pagou"]
# Out:
# ['id_cliente', 'idade', 'estado', 'dias_atraso', 'valor_divida', 'score_credito', 'status', 'data_contato', 'pagou']

# %%
X = df.drop("pagou", axis=1)
y = df["pagou"]

# %%
encoder = LabelEncoder()

for coluna in X.select_dtypes(include="object"):
    X[coluna] = encoder.fit_transform(X[coluna])

# %%
X_train, X_test, y_train, y_test = train_test_split(

X,
y,
test_size=0.30,
random_state=42
)

# %%
modelo = DecisionTreeClassifier()
modelo.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred= modelo.predict(X_test)

# %%
accuracy_score(y_test, pred)
# Out:
# 1.0

# %%
importancias = pd.DataFrame({
"Variavel": X.columns,
"Importancia":modelo.feature_importances_
})

importancias.sort_values(
"Importancia",
ascending=False
)
# Out:
#         Variavel  Importancia
# 6         status          1.0
# 0     id_cliente          0.0
# 2         estado          0.0
# 1          idade          0.0
# 3    dias_atraso          0.0
# 4   valor_divida          0.0
# 5  score_credito          0.0
# 7   data_contato          0.0

# %%
from pathlib import Path

output_path = Path(r"C:\Users\scarl\Desktop\Recuperacao_credito\dados\clientes_tratados.csv")
output_path.parent.mkdir(parents=True, exist_ok=True)

df.to_csv(output_path, index=False, encoding="utf-8-sig")
print("Exportados")
# Out:
# Exportados
